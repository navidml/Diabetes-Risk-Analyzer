# %%
import pandas as pd
from pycaret.classification import *

# %%
PATH = r"C:\Users\navid\OneDrive\دسکتاپ\projects\Diabetes Risk Analyzer\data\diabetes.csv"
df = pd.read_csv(PATH)

# %%
clf_setup = setup(data=df, 
                   target='Outcome', 
                   session_id=42, 
                   train_size=0.75)
# Out:
# <style type="text/css">
# #T_64bdb_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_64bdb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64bdb_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_64bdb_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64bdb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64bdb_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_64bdb_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_64bdb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64bdb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_64bdb_row1_col1" class="data row1 col1" >Outcome</td>
#     </tr>
#     <tr>
#       <th id="T_64bdb_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_23420 th {
#   text-align: left;
# }
# ...

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import NaviLib as nl 

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import StackingClassifier

import joblib
sns.set_style('whitegrid')
pd.set_option('display.max_columns', None)
# %matplotlib inline

from tqdm import tqdm

# %%
PATH = r"C:\Users\navid\OneDrive\دسکتاپ\projects\Diabetes Risk Analyzer\data\diabetes.csv"
df = pd.read_csv(PATH)

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
train , test = train_test_split(df , 
                                test_size=0.25 , 
                                random_state=42 , 
                                stratify=df['Outcome'])

# %%
print(f'train size:{train.shape}')
print(f'test size:{test.shape}')
# Out:
# train size:(576, 9)
# test size:(192, 9)

# %%
train.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
train.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
a , b , c =nl.xgboost_feature_analysis(df=df,
                            target='Outcome',
                            problem_type='classification',
                            test_size=0.25,
                            random_state=42,
                            n_estimators=600,
                            learning_rate=0.01
)

# %%
a
# Out:
#                     feature  gain_percent  perm_percent  combined_score
# 0                   Glucose     25.674843     49.029126       35.016556
# 1                       BMI     14.228199     20.388350       16.692259
# 2                       Age     14.854010     11.165049       13.378425
# 3  DiabetesPedigreeFunction      9.371702      7.766990        8.729817
# 4               Pregnancies      8.340090      5.582524        7.237063
# 5                   Insulin     10.273276      2.427184        7.134839
# 6             BloodPressure      8.322549      4.126214        6.644015
# 7             SkinThickness      8.935332     -0.485437        5.167025

# %%
b
# Out:
# ['Glucose',
#  'BMI',
#  'Age',
#  'DiabetesPedigreeFunction',
#  'Pregnancies',
#  'Insulin',
#  'BloodPressure',
#  'SkinThickness']

# %%
corr = df.corr(numeric_only=True)

mask = np.triu(np.ones_like(corr, dtype=bool))

plt.figure(figsize=(12,10))

sns.heatmap(
    corr,
    mask=mask,
    annot=True,
    cmap='RdBu_r',
    center=0,
    fmt='.2f'
)

plt.title('Feature Correlation Heatmap')
plt.show()

# %%
X_train = train.drop('Outcome' , axis=1)
y_train = train['Outcome']

X_test = train.drop('Outcome' , axis=1)
y_test = train['Outcome']

# %%
lr = LogisticRegression(class_weight='balanced',
                        max_iter=1000 ,
                        random_state=42)

# %%
param_grid_lr = {
    'C': [115 ,120 , 125],
    'solver': ['liblinear', 'lbfgs']
}

# %%
grid_lr = GridSearchCV(
    lr,
    param_grid_lr,
    cv=5,
    scoring='roc_auc',
    n_jobs=-1
)

# %%
grid_lr.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=LogisticRegression(class_weight='balanced',
#                                           max_iter=1000, random_state=42),
#              n_jobs=-1,
#              param_grid={'C': [115, 120, 125],
#                          'solver': ['liblinear', 'lbfgs']},
#              scoring='roc_auc')

# %%
best_lr = grid_lr.best_estimator_

# %%
rf = RandomForestClassifier(class_weight='balanced',
                            random_state=42)

# %%
param_grid_rf = {
    'n_estimators': [1500],
    'max_depth': [10],
    'min_samples_split': [20],
    'max_features': ['sqrt'],
}

# %%
grid_rf = GridSearchCV(
    rf,
    param_grid_rf,
    cv=5,
    scoring='roc_auc',
    verbose=3,
    n_jobs=-1
)

# %%
grid_rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [10], 'max_features': ['sqrt'],
#                          'min_samples_split': [20], 'n_estimators': [1500]},
#              scoring='roc_auc', verbose=3)

# %%
best_rf = grid_rf.best_estimator_

# %%
gb = GradientBoostingClassifier(
    random_state=42
)

# %%
param_grid_gb = {
    'n_estimators': [200],
    'learning_rate': [0.01],
}

# %%
grid_gb = GridSearchCV(
    gb,
    param_grid_gb,
    cv=5,
    scoring='roc_auc',
    verbose=3,
    n_jobs=-1
)

# %%
grid_gb.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(random_state=42),
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01], 'n_estimators': [200]},
#              scoring='roc_auc', verbose=3)

# %%
best_gb = grid_gb.best_estimator_

# %%
stack_model = StackingClassifier(
    estimators=[
        ('lr', best_lr),
        ('rf', best_rf),
        ('gb', best_gb)
    ],
    final_estimator=LogisticRegression(random_state=42),
    cv=5,
    n_jobs=-1
)

# %%
stack_model.fit(X_train, y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('lr',
#                                 LogisticRegression(C=115,
#                                                    class_weight='balanced',
#                                                    max_iter=1000,
#                                                    random_state=42)),
#                                ('rf',
#                                 RandomForestClassifier(class_weight='balanced',
#                                                        max_depth=10,
#                                                        min_samples_split=20,
#                                                        n_estimators=1500,
#                                                        random_state=42)),
#                                ('gb',
#                                 GradientBoostingClassifier(learning_rate=0.01,
#                                                            n_estimators=200,
#                                                            random_state=42))],
#                    final_estimator=LogisticRegression(random_state=42),
#                    n_jobs=-1)

# %%
y_prob = stack_model.predict_proba(X_test)[:,1]

y_pred = (y_prob >= 0.35).astype(int)

# %%
nl.evaluate_classification_model(y_true=y_test , y_pred=y_pred)
# Out:
# C:\Users\navid\OneDrive\دسکتاپ\projects\Diabetes Risk Analyzer\.venv\Lib\site-packages\NaviLib\evaluation.py:423: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# {'accuracy': 0.8229166666666666,
#  'precision_macro': 0.8054657765021527,
#  'recall_macro': 0.8247562189054727,
#  'f1_macro': 0.8117984726564502,
#  'precision_weighted': 0.8341115773382417,
#  'recall_weighted': 0.8229166666666666,
#  'f1_weighted': 0.8256167994977193,
#  'kappa': 0.6249856382367585,
#  'mcc': 0.629926695995219,
#  'precision_0': np.float64(0.9002932551319648),
#  'recall_0': np.float64(0.8186666666666667),
#  'f1_0': np.float64(0.8575418994413407),
#  'precision_1': np.float64(0.7106382978723405),
#  'recall_1': np.float64(0.8308457711442786),
#  'f1_1': np.float64(0.7660550458715596),
#  'precision_positive': 0.7106382978723405,
#  'recall_positive': 0.8308457711442786,
#  'f1_positive': 0.7660550458715596,
#  'specificity': 0.8186666666666667}

# %%
joblib.dump(stack_model, 'diabetes_prediction_model.pkl')
# Out:
# ['diabetes_prediction_model.pkl']
